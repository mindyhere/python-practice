# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

image = cv2.imread("c:/images/plane.jpg", cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(image, cmap="gray")
plt.axis("off")
plt.show()

# %%
type(image)
# Out:
# numpy.ndarray

# %%
image
# Out:
# array([[140, 138, 145, ..., 133, 139, 134],
#        [142, 137, 151, ..., 143, 125, 125],
#        [153, 137, 145, ..., 120, 129, 135],
#        ...,
#        [153, 151, 144, ..., 153, 154, 148],
#        [151, 146, 145, ..., 158, 160, 158],
#        [140, 140, 145, ..., 154, 157, 159]], dtype=uint8)

# %%
image.shape
# Out:
# (2270, 3600)

# %%
image_bgr = cv2.imread("c:/images/plane.jpg", cv2.IMREAD_COLOR)
image_bgr.shape
image_bgr
# Out:
# array([[[140, 140, 140],
#         [138, 138, 138],
#         [145, 145, 145],
#         ...,
#         [133, 133, 133],
#         [139, 139, 139],
#         [134, 134, 134]],
#
#        [[142, 142, 142],
#         [137, 137, 137],
#         [151, 151, 151],
#         ...,
#         [143, 143, 143],
#         [125, 125, 125],
#         [125, 125, 125]],
#
#        [[153, 153, 153],
#         [137, 137, 137],
#         [145, 145, 145],
#         ...,
#         [120, 120, 120],
#         [129, 129, 129],
#         [135, 135, 135]],
#
#        ...,
#
#        [[153, 153, 153],
#         [151, 151, 151],
#         [144, 144, 144],
#         ...,
#         [153, 153, 153],
#         [154, 154, 154],
#         [148, 148, 148]],
#
#        [[151, 151, 151],
#         [146, 146, 146],
#         [145, 145, 145],
#         ...,
#         [158, 158, 158],
#         [160, 160, 160],
#         [158, 158, 158]],
#
#        [[140, 140, 140],
#         [140, 140, 140],
#         [145, 145, 145],
# ...

# %%
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)
plt.axis("off")
plt.show()

# %%
cv2.imwrite("c:/images/plane_new.jpg", image)
# Out:
# True

# %%
imgage = cv2.imread("c:/images/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)

image_50x50 = cv2.resize(image, (50, 50))
print(image_50x50.shape)

plt.imshow(image_50x50, cmap="gray")
plt.axis("off")
plt.show()
# Out:
# (50, 50)

# %%
image = cv2.imread("c:/images/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)

image_cropped = image[:, :128]

plt.imshow(image_cropped, cmap="gray")
plt.show()

# %%
image = cv2.imread("c:/images/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)
# image_blurry = cv2.blur(image, (5, 5))
image_blurry = cv2.blur(image, (10, 10))

plt.imshow(image_blurry, cmap="gray"), plt.axis("off")
plt.show()

# %%
kernel = np.ones((5, 5)) / 25.0

print(sum(kernel.flatten()))
print(kernel)
# Out:
# 1.0000000000000002
# [[0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]]

# %%
image_kernel = cv2.filter2D(image, -1, kernel)

plt.imshow(image_kernel, cmap="gray"), plt.xticks([]), plt.yticks([])
plt.show()

# %%
image = cv2.imread("c:/images/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)
kernel = np.array([[0, -1, 0], [-1, 5, -1], [0, -1, 0]])

image_sharp = cv2.filter2D(image, -1, kernel)

plt.imshow(image_sharp, cmap="gray"), plt.axis("off")
plt.show()

# %%
image = cv2.imread("c:/images/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)
image_enghanced = cv2.equalizeHist(image)
plt.imshow(image_enghanced, cmap="gray"), plt.axis("off")
plt.show()

# %%
image_gray = cv2.imread("c:/images/plane_256x256.jpg", cv2.IMREAD_GRAYSCALE)
median_intensity = np.median(image_gray)
lower_threshold = int(max(0, (1.0 - 0.33) * median_intensity))
upper_threshold = int(min(255, (1.0 + 0.33) * median_intensity))
image_canny = cv2.Canny(image_gray, lower_threshold, upper_threshold)
plt.imshow(image_canny, cmap="gray"), plt.axis("off")
plt.show()
