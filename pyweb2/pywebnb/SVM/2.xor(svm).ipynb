# %%
import numpy as np
import mglearn

X_train = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
# X or Y
y_train = [0, 1, 1, 0]
mglearn.discrete_scatter(X_train[:, 0], X_train[:, 1], y_train)
# Out:
# [<matplotlib.lines.Line2D at 0x23747d28350>,
#  <matplotlib.lines.Line2D at 0x23747cab080>]

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# svm=SVC(kernel='linear') # 선형, 직선
svm = SVC(kernel="rbf")  # 비선형, 곡선
svm.fit(X_train, y_train)

# 예측
X_test = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
pred = svm.predict(X_test)

# 평가
print(X_test, "의 예측결과 :", pred)
print("정답률 :", accuracy_score([0, 1, 1, 0], pred))
# Out:
# [[0 0]
#  [0 1]
#  [1 0]
#  [1 1]] 의 예측결과 : [0 1 1 0]
# 정답률 : 1.0

# %%
mglearn.discrete_scatter(X_train[:, 0], X_train[:, 1], y_train)
mglearn.plots.plot_2d_classification(svm, X_train, cm="spring")
